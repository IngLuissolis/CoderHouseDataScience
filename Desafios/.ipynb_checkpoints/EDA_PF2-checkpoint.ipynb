# %% [markdown]
# ## Datos de Interes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ruta_archivo = '../DataSets/european_leagues_player_stats/Big5-statsStats22-23_Corr.csv'

df = pd.read_csv(ruta_archivo, delimiter=',')

# Ver las primeras filas del dataset
df.head()
# Out:
#    Unnamed: 0            Player   Nation    Pos           Squad  \
# 0           0  Brenden Aaronson   us USA  MF,FW    Leeds United
# 1           1   Paxten Aaronson   us USA  MF,DF  Eint Frankfurt
# 2           2    James Abankwah   ie IRL     DF         Udinese
# 3           3     George Abbott  eng ENG     MF       Tottenham
# 4           4  Yunis Abdelhamid   ma MAR     DF           Reims
#
#                  Comp  Age  Born  MP  Starts  ... Gls.1  Ast.1  G+A.1  G-PK.1  \
# 0  eng Premier League   21  2000  36      28  ...  0.04   0.11   0.15    0.04
# 1       de Bundesliga   18  2003   7       0  ...  0.00   0.00   0.00    0.00
# 2          it Serie A   18  2004   2       1  ...  0.00   0.00   0.00    0.00
# 3  eng Premier League   16  2005   1       0  ...  0.00   0.00   0.00    0.00
# 4          fr Ligue 1   34  1987  37      37  ...  0.03   0.05   0.08    0.03
#
#    G+A-PK  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1
# 0    0.15  0.15   0.16    0.31    0.15        0.31
# ...

# %% [markdown]
# ## Analisis Exploratorio de Datos (EDA)

# %%
# Obtener información sobre el conjunto de datos
df.info()

# Calcular estadísticas descriptivas
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2872 entries, 0 to 2871
# Data columns (total 37 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2872 non-null   int64
#  1   Player      2872 non-null   object
#  2   Nation      2872 non-null   object
#  3   Pos         2872 non-null   object
#  4   Squad       2872 non-null   object
#  5   Comp        2872 non-null   object
#  6   Age         2872 non-null   int64
#  7   Born        2872 non-null   int64
#  8   MP          2872 non-null   int64
#  9   Starts      2872 non-null   int64
#  10  Min         2872 non-null   object
#  11  90s         2872 non-null   float64
#  12  Gls         2872 non-null   int64
#  13  Ast         2872 non-null   int64
#  14  G+A         2872 non-null   int64
#  15  G-PK        2872 non-null   int64
#  16  PK          2872 non-null   int64
#  17  PKatt       2872 non-null   int64
#  18  CrdY        2872 non-null   int64
# ...

# %%
# Visualización univariada - Histograma de edad
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', kde=True)
plt.title('Distribución de la Edad de los Jugadores')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Visualización bivariada: Relación entre posición y asistencias
# Ordenar el DataFrame por la columna 'Assists' de forma descendente
df_sorted = df.sort_values('Ast', ascending=False)
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_sorted, x='Pos', y='Ast')
plt.title('Relación entre posición y Asistencias (ordenado de mayor a menor)')
plt.xlabel('Posición')
plt.ylabel('Asistencias')
plt.show()

# %% [markdown]
# ### Resultados Visualización bivariada
#
#     En el grafico anterior se observa una mayor de cantidad de asistencias por parte de la posición MF
#     seguido por la posición FW.

# %%
# Punto fuera de rango 
# Obtener el índice del máximo valor en la columna 'Assists'
max_assist_index = df['Ast'].idxmax()

# Obtener el nombre del jugador máximo asistidor
max_assist_player = df.loc[max_assist_index, 'Player']

# Obtener el nombre del equipo máximo asistidor
max_assist_squad = df.loc[max_assist_index, 'Squad']

# Obtener la cantidad de goles del jugador máximo goleador
max_assists = df.loc[max_assist_index, 'Ast']

print("El jugador máximo asistidor es:", max_assist_player)
print("Cantidad de asistencias:", max_assists)
print("Juega en el equipo:", max_assist_squad)
# Out:
# El jugador máximo asistidor es: Kevin De Bruyne
# Cantidad de asistencias: 16
# Juega en el equipo: Manchester City

# %%
# Visualización trivariada: Relación entre edad, goles y posición
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='Age', y='Gls', hue='Pos')
plt.title('Relación entre Edad, Goles y Posición')
plt.xlabel('Edad')
plt.ylabel('Goles')
plt.legend(title='Posición')
plt.show()

# %% [markdown]
# ### Resultados Visualización trivariada
#
# En el grafico anterior no se observa correlación entre edad y cantidad de goles. Si un rango minimo (20 años) y maximo (36 años) de promedio de goles.
#
# Se observa ademas una correlación entre posición y cantidad de goles, la posición FW es la que proporciona mayor cantidad
# de goles,lo cual es logico ya que es la posición mas cercana al arco contrario.

# %% [markdown]
# # 1. ¿Cuáles son los jugadores más efectivos en términos de goles marcados? ¿Existen diferencias significativas entre los distintos equipos en cuanto a la producción de goles?

# %%
# Agrupar los datos por jugador y sumar los goles marcados por cada jugador
jugadores_goles = df.groupby(['Player', 'Squad'])['Gls'].sum().reset_index()

# Ordenar los jugadores por la cantidad de goles en orden descendente
jugadores_top15 = jugadores_goles.nlargest(15, 'Gls')

# Mostrar los 15 jugadores más efectivos en términos de goles marcados
jugadores_top15.head(15)
# Out:
#                    Player            Squad  Gls
# 763        Erling Haaland  Manchester City   36
# 1010           Harry Kane        Tottenham   30
# 1527        Kylian Mbappé        Paris S-G   29
# 123   Alexandre Lacazette             Lyon   27
# 2712       Victor Osimhen           Napoli   26
# 1290       Jonathan David            Lille   24
# 2317   Robert Lewandowski        Barcelona   23
# 869       Folarin Balogun            Reims   21
# 1543     Lautaro Martínez            Inter   21
# 1608          Loïs Openda             Lens   21
# 993          Habib Diallo       Strasbourg   20
# 1104           Ivan Toney        Brentford   20
# 719             Elye Wahi      Montpellier   19
# 1430        Karim Benzema      Real Madrid   19
# 1951        Mohamed Salah        Liverpool   19

# %%
# Agrupar los datos por jugador y sumar las asistencias por cada jugador
jugadores_goles = df.groupby(['Player', 'Squad'])['Ast'].sum().reset_index()

# Ordenar los jugadores por la cantidad de asistencias en orden descendente
jugadores_top15 = jugadores_goles.nlargest(15, 'Ast')

# Mostrar los 15 jugadores más efectivos en términos de asistencias
jugadores_top15.head(15)
# Out:
#                      Player            Squad  Ast
# 222       Antoine Griezmann  Atlético Madrid   16
# 1465        Kevin De Bruyne  Manchester City   16
# 1588           Lionel Messi        Paris S-G   16
# 1951          Mohamed Salah        Liverpool   12
# 2268      Raphaël Guerreiro         Dortmund   12
# 390             Bukayo Saka          Arsenal   11
# 1906          Michael Olise   Crystal Palace   11
# 2038                 Neymar        Paris S-G   11
# 2262      Randal Kolo Muani   Eint Frankfurt   11
# 324     Benjamin Bourigeaud           Rennes   10
# 857           Florian Kainz             Köln   10
# 1149          Jamal Musiala    Bayern Munich   10
# 1481  Khvicha Kvaratskhelia           Napoli   10
# 1553       Leandro Trossard          Arsenal   10
# 2313           Riyad Mahrez  Manchester City   10

# %%
# Agrupar los datos por equipo y sumar los goles marcados por cada equipo
equipos_goles = df.groupby('Squad')['Gls'].sum().reset_index()

# Ordenar los equipos por la cantidad de goles en orden descendente
equipos_top10 = equipos_goles.nlargest(10, 'Gls')

# Mostrar los diez equipos con mayor cantidad de goles
print(equipos_top10)

# Gráfico de barras para visualizar la producción de goles de los equipos top 10
plt.figure(figsize=(10, 6))
plt.bar(equipos_top10['Squad'], equipos_top10['Gls'])
plt.xlabel('Equipo')
plt.ylabel('Goles')
plt.title('Producción de goles de los diez equipos con mayor cantidad de goles')
plt.xticks(rotation=90)
plt.show()
# Out:
#               Squad  Gls
# 55  Manchester City   92
# 11    Bayern Munich   90
# 68        Paris S-G   86
# 3           Arsenal   84
# 25         Dortmund   81
# 63           Napoli   75
# 71      Real Madrid   73
# 49        Liverpool   70
# 10        Barcelona   69
# 59           Monaco   69

# %% [markdown]
# ### Variables de Ataque
#
#     PrgC: El porcentaje de pases completados por el jugador.
#
#     PrgP: El número de pases progresivos completados por el jugador.
#
#     PrgR: El número de pases progresivos que han conducido a una oportunidad de gol creada por el jugador.
#
#     Gls: El número de goles marcados por el jugador.

# %%
# Filtrar los datos para obtener solo los jugadores del equipo Bayern Munich
bayern_munich = df[df['Squad'] == 'Bayern Munich']

# Agrupar los datos por jugador y sumar los goles marcados por cada jugador
bayer_munich_goles = bayern_munich.groupby(['Player', 'Pos', 'PrgC', 'PrgP', 'PrgR'])['Gls'].sum().reset_index()
bayer_munich_goles = bayer_munich_goles[bayer_munich_goles['Gls'] >= 1]

# Ordenar los jugadores por la cantidad de goles en orden descendente
bayer_munich_goles = bayer_munich_goles.sort_values(by='Gls', ascending=False)

# Mostrar los jugadores del equipo Bayer Munich con más de 1 gol
print("Jugadores del equipo Bayer Munich con al menos 1 gol:")
print(bayer_munich_goles)

# Calcular el total de goles del equipo Bayer Munich
bayer_munich_total_goles = bayer_munich_goles['Gls'].sum()
print("Total de goles del equipo Bayer Munich:", bayer_munich_total_goles)

print("")

# Filtrar los datos para obtener solo los jugadores del equipo Manchester City
Manchester_City = df[df['Squad'] == 'Manchester City']

# Agrupar los datos por jugador y sumar los goles marcados por cada jugador
Manchester_City_goles = Manchester_City.groupby(['Player', 'Pos', 'PrgC', 'PrgP', 'PrgR'])['Gls'].sum().reset_index()
Manchester_City_goles = Manchester_City_goles[Manchester_City_goles['Gls'] >= 1]

# Ordenar los jugadores por la cantidad de goles en orden descendente
Manchester_City_goles = Manchester_City_goles.sort_values(by='Gls', ascending=False)

# Mostrar los jugadores del equipo Manchester City con más de 1 gol
print("Jugadores del equipo Manchester City con al menos 1 gol:")
print(Manchester_City_goles)

# Calcular el total de goles del equipo Manchester City
Manchester_City_total_goles = Manchester_City_goles['Gls'].sum()
print("Total de goles del equipo Manchester City:", Manchester_City_total_goles)

print("")

# Filtrar los datos para obtener solo los jugadores del equipo Paris_S-G
Paris_SG = df[df['Squad'] == 'Paris S-G']

# Agrupar los datos por jugador y sumar los goles marcados por cada jugador
Paris_SG_goles = Paris_SG.groupby(['Player', 'Pos', 'PrgC', 'PrgP', 'PrgR'])['Gls'].sum().reset_index()
Paris_SG_goles = Paris_SG_goles[Paris_SG_goles['Gls'] >= 1]

# Ordenar los jugadores por la cantidad de goles en orden descendente
Paris_SG_goles = Paris_SG_goles.sort_values(by='Gls', ascending=False)

# Mostrar los jugadores del equipo Paris_S-G con más de 1 gol
print("Jugadores del equipo Paris S-G con al menos 1 gol:")
print(Paris_SG_goles)

# Calcular el total de goles del equipo Paris S-G
Paris_SG_total_goles = Paris_SG_goles['Gls'].sum()
print("Total de goles del equipo Paris S-G:", Paris_SG_total_goles)
# Out:
# Jugadores del equipo Bayer Munich con al menos 1 gol:
#                       Player    Pos   PrgC   PrgP   PrgR  Gls
# 24              Serge Gnabry  FW,MF   74.0   82.0  217.0   14
# 8              Jamal Musiala  MF,FW   89.0  124.0  196.0   12
# 6   Eric Maxim Choupo-Moting     FW   11.0   43.0   77.0   10
# 12            Kingsley Coman  FW,MF   98.0   70.0  296.0    8
# 14                Leroy Sané  MF,FW   77.0  134.0  198.0    8
# 23                Sadio Mané  FW,MF   59.0   43.0  164.0    7
# 26             Thomas Müller  FW,MF   33.0   88.0  182.0    7
# 9             Joshua Kimmich     MF   42.0  315.0   56.0    5
# 18                Mathys Tel     FW   12.0   11.0   59.0    5
# 2            Benjamin Pavard     DF   37.0  202.0   65.0    4
# 13             Leon Goretzka     MF   42.0  114.0   62.0    3
# 19          Matthijs de Ligt     DF   17.0  143.0   14.0    3
# 0            Alphonso Davies     DF  117.0  133.0  158.0    1
# ...

# %% [markdown]
# ### 2. ¿Existe una relación entre la precisión de los pases de un jugador y su capacidad para crear oportunidades de gol para su equipo?
#
#     PrgR: El número de pases progresivos que han conducido a una oportunidad de gol creada por el jugador.
#
#     Gls: El número de goles marcados por el jugador.

# %%
# Extraer las columnas PrgR y Gls equipo Bayer Munich
pases = bayer_munich_goles["PrgR"].to_list()
goles = bayer_munich_goles["Gls"].to_list()
jugadores = bayer_munich_goles["Player"].to_list()

# Crear el gráfico de dispersión
plt.figure(figsize=(8, 6))
plt.scatter(pases, goles, c='blue', alpha=0.7)

# Agregar etiquetas de los jugadores
for i, jugador in enumerate(jugadores):
    plt.annotate(jugador, (pases[i], goles[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Agregar títulos y etiquetas de los ejes
plt.title("Relación entre precisión de pases y número de goles (Equipo Bayer Munich)")
plt.xlabel("Precisión de pases (PrgR)")
plt.ylabel("Número de goles")

# Mostrar el gráfico
plt.show()

# %%
# Extraer las columnas PrgR y Gls equipo Manchester_City
pases = Manchester_City_goles["PrgR"].to_list()
goles = Manchester_City_goles["Gls"].to_list()
jugadores = Manchester_City_goles["Player"].to_list()

# Crear el gráfico de dispersión
plt.figure(figsize=(8, 6))
plt.scatter(pases, goles, c='blue', alpha=0.7)

# Agregar etiquetas de los jugadores
for i, jugador in enumerate(jugadores):
    plt.annotate(jugador, (pases[i], goles[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Agregar títulos y etiquetas de los ejes
plt.title("Relación entre precisión de pases y número de goles (Equipo Manchester City)")
plt.xlabel("Precisión de pases (PrgR)")
plt.ylabel("Número de goles")

# Mostrar el gráfico
plt.show()

# %%
# Extraer las columnas PrgR y Gls equipo Paris SG
pases = Paris_SG_goles["PrgR"].to_list()
goles = Paris_SG_goles["Gls"].to_list()
jugadores = Paris_SG_goles["Player"].to_list()

# Crear el gráfico de dispersión
plt.figure(figsize=(8, 6))
plt.scatter(pases, goles, c='blue', alpha=0.7)

# Agregar etiquetas de los jugadores
for i, jugador in enumerate(jugadores):
    plt.annotate(jugador, (pases[i], goles[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Agregar títulos y etiquetas de los ejes
plt.title("Relación entre precisión de pases y número de goles (Equipo Paris SG)")
plt.xlabel("Precisión de pases (PrgR)")
plt.ylabel("Número de goles")

# Mostrar el gráfico
plt.show()
