# %% [markdown]
# ## Datos de Interes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ruta_archivo = '../DataSets/player_stats/standard_stats_Corr.csv'

df = pd.read_csv(ruta_archivo, delimiter=',')

# Ver las primeras filas del dataset
df.head()
# Out:
#    Unnamed: 0     Season League     Team Unnamed: 0_level_0_Player  \
# 0       91649  2022-2023    EPL  Arsenal        Gabriel Dos Santos
# 1       91650  2022-2023    EPL  Arsenal            Aaron Ramsdale
# 2       91651  2022-2023    EPL  Arsenal            William Saliba
# 3       91652  2022-2023    EPL  Arsenal               Bukayo Saka
# 4       91653  2022-2023    EPL  Arsenal           Martin Ødegaard
#
#   Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  Unnamed: 3_level_0_Age  \
# 0                    br BRA                     DF                    25.0
# 1                   eng ENG                     GK                    24.0
# 2                    fr FRA                     DF                    21.0
# 3                   eng ENG                     FW                    21.0
# 4                    no NOR                     MF                    24.0
#
#    Playing Time_Starts  Playing Time_Min  ...  Per 90 Minutes_G+A-PK  \
# 0                 27.0            2430.0  ...                   0.11
# 1                 27.0            2430.0  ...                   0.00
# 2                 27.0            2415.0  ...                   0.11
# 3                 27.0            2313.0  ...                   0.66
# 4                 26.0            2216.0  ...                   0.65
#
#    Expected_xG  Expected_npxG  Expected_xAG  Expected_npxG+xAG  \
# 0          3.5            3.5           0.2                3.6
# 1          0.0            0.0           0.0                0.0
# 2          0.9            0.9           1.1                2.0
# 3          8.7            7.3           6.1               13.4
# 4          7.0            7.0           6.3               13.4
#
#    Per 90 Minutes_xG  Per 90 Minutes_xAG  Per 90 Minutes_xG+xAG  \
# 0               0.13                0.01                   0.14
# 1               0.00                0.00                   0.00
# 2               0.03                0.04                   0.08
# 3               0.35                0.24                   0.59
# 4               0.30                0.27                   0.57
#
#    Per 90 Minutes_npxG  Per 90 Minutes_npxG+xAG
# 0                 0.13                     0.14
# 1                 0.00                     0.00
# 2                 0.03                     0.08
# 3                 0.29                     0.54
# 4                 0.30                     0.57
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Analisis Exploratorio de Datos (EDA)

# %%
# Obtener información sobre el conjunto de datos
df.info()

# Calcular estadísticas descriptivas
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2745 entries, 0 to 2744
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 2745 non-null   int64
#  1   Season                     2745 non-null   object
#  2   League                     2745 non-null   object
#  3   Team                       2745 non-null   object
#  4   Unnamed: 0_level_0_Player  2745 non-null   object
#  5   Unnamed: 1_level_0_Nation  2745 non-null   object
#  6   Unnamed: 2_level_0_Pos     2745 non-null   object
#  7   Unnamed: 3_level_0_Age     2745 non-null   float64
#  8   Playing Time_Starts        2745 non-null   float64
#  9   Playing Time_Min           2745 non-null   float64
#  10  Playing Time_90s           2745 non-null   float64
#  11  Performance_Gls            2745 non-null   float64
#  12  Performance_Ast            2745 non-null   float64
#  13  Performance_G+A            2745 non-null   float64
#  14  Performance_G-PK           2745 non-null   float64
#  15  Performance_PK             2745 non-null   float64
#  16  Performance_PKatt          2745 non-null   float64
#  17  Performance_CrdY           2745 non-null   float64
#  18  Performance_CrdR           2745 non-null   float64
#  19  Progression_PrgC           2745 non-null   float64
#  20  Progression_PrgP           2745 non-null   float64
#  21  Progression_PrgR           2745 non-null   float64
#  22  Per 90 Minutes_Gls         2745 non-null   float64
#  23  Per 90 Minutes_Ast         2745 non-null   float64
#  24  Per 90 Minutes_G+A         2745 non-null   float64
#  25  Per 90 Minutes_G-PK        2745 non-null   float64
#  26  Per 90 Minutes_G+A-PK      2745 non-null   float64
#  27  Expected_xG                2745 non-null   float64
#  28  Expected_npxG              2745 non-null   float64
#  29  Expected_xAG               2745 non-null   float64
#  30  Expected_npxG+xAG          2745 non-null   float64
#  31  Per 90 Minutes_xG          2745 non-null   float64
#  32  Per 90 Minutes_xAG         2745 non-null   float64
#  33  Per 90 Minutes_xG+xAG      2745 non-null   float64
#  34  Per 90 Minutes_npxG        2745 non-null   float64
#  35  Per 90 Minutes_npxG+xAG    2745 non-null   float64
# dtypes: float64(29), int64(1), object(6)
# memory usage: 772.2+ KB
#          Unnamed: 0  Unnamed: 3_level_0_Age  Playing Time_Starts  \
# count   2745.000000             2745.000000          2745.000000
# mean   93420.299818               26.058652            10.052095
# std     1016.352046                4.500630             8.199800
# min    91649.000000               15.000000             0.000000
# 25%    92547.000000               23.000000             2.000000
# 50%    93420.000000               26.000000             9.000000
# 75%    94297.000000               29.000000            17.000000
# max    95194.000000               41.000000            27.000000
#
#        Playing Time_Min  Playing Time_90s  Performance_Gls  Performance_Ast  \
# count       2745.000000       2745.000000      2745.000000      2745.000000
# mean         901.985064         10.022441         1.200364         0.837887
# std          695.909568          7.732157         2.320981         1.433011
# min            1.000000          0.000000         0.000000         0.000000
# 25%          266.000000          3.000000         0.000000         0.000000
# 50%          790.000000          8.800000         0.000000         0.000000
# 75%         1480.000000         16.400000         1.000000         1.000000
# max         2430.000000         27.000000        28.000000        13.000000
#
#        Performance_G+A  Performance_G-PK  Performance_PK  ...  \
# count      2745.000000       2745.000000     2745.000000  ...
# mean          2.038251          1.092168        0.108197  ...
# std           3.270316          2.067174        0.511837  ...
# min           0.000000          0.000000        0.000000  ...
# 25%           0.000000          0.000000        0.000000  ...
# 50%           1.000000          0.000000        0.000000  ...
# 75%           3.000000          1.000000        0.000000  ...
# max          33.000000         23.000000        6.000000  ...
#
#        Per 90 Minutes_G+A-PK  Expected_xG  Expected_npxG  Expected_xAG  \
# count            2745.000000  2745.000000    2745.000000   2745.000000
# mean                0.191665     1.188597       1.080947      0.842914
# std                 0.434043     1.916948       1.669528      1.185531
# min                 0.000000     0.000000       0.000000      0.000000
# 25%                 0.000000     0.100000       0.100000      0.000000
# 50%                 0.070000     0.500000       0.500000      0.400000
# 75%                 0.270000     1.400000       1.400000      1.100000
# max                10.000000    18.900000      15.700000     10.400000
#
#        Expected_npxG+xAG  Per 90 Minutes_xG  Per 90 Minutes_xAG  \
# count        2745.000000        2745.000000         2745.000000
# mean            1.924554           0.129800            0.090710
# std             2.575748           0.201319            0.173687
# min             0.000000           0.000000            0.000000
# 25%             0.200000           0.020000            0.010000
# 50%             1.000000           0.060000            0.060000
# 75%             2.500000           0.180000            0.130000
# max            20.600000           4.570000            6.120000
#
#        Per 90 Minutes_xG+xAG  Per 90 Minutes_npxG  Per 90 Minutes_npxG+xAG
# count            2745.000000          2745.000000              2745.000000
# mean                0.220605             0.121144                 0.211927
# std                 0.284501             0.191203                 0.275572
# min                 0.000000             0.000000                 0.000000
# 25%                 0.050000             0.010000                 0.050000
# 50%                 0.140000             0.060000                 0.140000
# 75%                 0.320000             0.160000                 0.300000
# max                 6.120000             4.570000                 6.120000
#
# [8 rows x 30 columns]

# %%
# Visualización univariada - Histograma de edad
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Unnamed: 3_level_0_Age', kde=True)
plt.title('Distribución de la Edad de los Jugadores')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Visualización bivariada: Relación entre posición y asistencias
# Ordenar el DataFrame por la columna 'Assists' de forma descendente
df_sorted = df.sort_values('Performance_Ast', ascending=False)
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_sorted, x='Unnamed: 2_level_0_Pos', y='Performance_Ast')
plt.title('Relación entre posición y Asistencias (ordenado de mayor a menor)')
plt.xlabel('Posición')
plt.ylabel('Asistencias')
plt.show()

# %% [markdown]
# ### Resultados Visualización bivariada
#
#     En el grafico anterior se observa una mayor de cantidad de asistencias por parte de la posición MF
#     seguido por la posición FW.

# %%
# Punto fuera de rango 
# Obtener el índice del máximo valor en la columna 'Assists'
max_assist_index = df['Performance_Ast'].idxmax()

# Obtener el nombre del jugador máximo asistidor
max_assist_player = df.loc[max_assist_index, 'Unnamed: 0_level_0_Player']

# Obtener el nombre del equipo máximo asistidor
max_assist_squad = df.loc[max_assist_index, 'Team']

# Obtener la cantidad de goles del jugador máximo goleador
max_assists = df.loc[max_assist_index, 'Performance_Ast']

print("El jugador máximo asistidor es:", max_assist_player)
print("Cantidad de asistencias:", max_assists)
print("Juega en el equipo:", max_assist_squad)
# Out:
# El jugador máximo asistidor es: Lionel Messi
# Cantidad de asistencias: 13.0
# Juega en el equipo: Paris S-G

# %%
# Visualización trivariada: Relación entre edad, goles y posición
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='Unnamed: 3_level_0_Age', y='Performance_Gls', hue='Unnamed: 2_level_0_Pos')
plt.title('Relación entre Edad, Goles y Posición')
plt.xlabel('Edad')
plt.ylabel('Goles')
plt.legend(title='Posición')
plt.show()

# %% [markdown]
# ### Resultados Visualización trivariada
#
# En el grafico anterior no se observa correlación entre edad y cantidad de goles. Si un rango minimo (20 años) y maximo (36 años) de promedio de goles.
#
# Se observa ademas una correlación entre posición y cantidad de goles, la posición FW es la que proporciona mayor cantidad
# de goles,lo cual es logico ya que es la posición mas cercana al arco contrario.

# %% [markdown]
# # 1. ¿Cuáles son los jugadores más efectivos en términos de goles marcados? ¿Existen diferencias significativas entre los distintos equipos en cuanto a la producción de goles?

# %%
# Agrupar los datos por jugador y sumar los goles marcados por cada jugador
jugadores_goles = df.groupby(['Unnamed: 0_level_0_Player', 'Team'])['Performance_Gls'].sum().reset_index()

# Ordenar los jugadores por la cantidad de goles en orden descendente
jugadores_top15 = jugadores_goles.nlargest(15, 'Performance_Gls')

# Mostrar los 15 jugadores más efectivos en términos de goles marcados
jugadores_top15.head(15)
# Out:
#      Unnamed: 0_level_0_Player             Team  Performance_Gls
# 729             Erling Haaland  Manchester City             28.0
# 968                 Harry Kane        Tottenham             20.0
# 1236            Jonathan David            Lille             19.0
# 1459             Kylian Mbappé        Paris S-G             19.0
# 2586            Victor Osimhen           Napoli             19.0
# 117        Alexandre Lacazette             Lyon             16.0
# 831            Folarin Balogun            Reims             16.0
# 2637         Wissam Ben Yedder           Monaco             16.0
# 1060                Ivan Toney        Brentford             15.0
# 1949           Niclas Füllkrug    Werder Bremen             15.0
# 2213        Robert Lewandowski        Barcelona             15.0
# 1473          Lautaro Martínez            Inter             14.0
# 1677           Marcus Rashford   Manchester Utd             14.0
# 951               Habib Diallo       Strasbourg             13.0
# 1516              Lionel Messi        Paris S-G             13.0

# %%
# Agrupar los datos por jugador y sumar las asistencias por cada jugador
jugadores_goles = df.groupby(['Unnamed: 0_level_0_Player', 'Team'])['Performance_Ast'].sum().reset_index()

# Ordenar los jugadores por la cantidad de asistencias en orden descendente
jugadores_top15 = jugadores_goles.nlargest(15, 'Performance_Ast')

# Mostrar los 15 jugadores más efectivos en términos de asistencias
jugadores_top15.head(15)
# Out:
#          Unnamed: 0_level_0_Player             Team  Performance_Ast
# 1516                  Lionel Messi        Paris S-G             13.0
# 1399               Kevin De Bruyne  Manchester City             12.0
# 1947                        Neymar        Paris S-G             11.0
# 2158             Randal Kolo Muani   Eint Frankfurt             10.0
# 373                    Bukayo Saka          Arsenal              9.0
# 1415         Khvicha Kvaratskhelia           Napoli              9.0
# 63                   Alassane Pléa       M'Gladbach              8.0
# 213              Antoine Griezmann  Atlético Madrid              8.0
# 639             Dominik Szoboszlai       RB Leipzig              8.0
# 800                   Filip Kostić         Juventus              8.0
# 1101                 Jamal Musiala    Bayern Munich              8.0
# 1235               Jonathan Clauss        Marseille              8.0
# 2369       Sergej Milinković-Savić            Lazio              8.0
# 351          Branco van den Boomen         Toulouse              7.0
# 376   Caio Henrique Oliveira Silva           Monaco              7.0

# %%
# Agrupar los datos por equipo y sumar los goles marcados por cada equipo
equipos_goles = df.groupby('Team')['Performance_Gls'].sum().reset_index()

# Ordenar los equipos por la cantidad de goles en orden descendente
equipos_top10 = equipos_goles.nlargest(10, 'Performance_Gls')

# Mostrar los diez equipos con mayor cantidad de goles
print(equipos_top10)

# Gráfico de barras para visualizar la producción de goles de los equipos top 10
plt.figure(figsize=(10, 6))
plt.bar(equipos_top10['Team'], equipos_top10['Performance_Gls'])
plt.xlabel('Equipo')
plt.ylabel('Goles')
plt.title('Producción de goles de los diez equipos con mayor cantidad de goles')
plt.xticks(rotation=90)
plt.show()
# Out:
#                Team  Performance_Gls
# 11    Bayern Munich             70.0
# 68        Paris S-G             66.0
# 55  Manchester City             65.0
# 3           Arsenal             59.0
# 63           Napoli             59.0
# 59           Monaco             54.0
# 71      Real Madrid             50.0
# 48            Lille             49.0
# 69       RB Leipzig             49.0
# 10        Barcelona             47.0

# %%
# Filtrar los datos para obtener solo los jugadores del equipo Bayern Munich
bayern_munich = df[df['Team'] == 'Bayern Munich']

# Agrupar los datos por jugador y sumar los goles marcados por cada jugador
bayer_munich_goles = bayern_munich.groupby(['Unnamed: 0_level_0_Player', 'Unnamed: 2_level_0_Pos', 'Progression_PrgC', 'Progression_PrgP', 'Progression_PrgR'])['Performance_Gls'].sum().reset_index()
bayer_munich_goles = bayer_munich_goles[bayer_munich_goles['Performance_Gls'] >= 1]

# Ordenar los jugadores por la cantidad de goles en orden descendente
bayer_munich_goles = bayer_munich_goles.sort_values(by='Performance_Gls', ascending=False)

# Mostrar los jugadores del equipo Bayer Munich con más de 1 gol
print("Jugadores del equipo Bayer Munich con al menos 1 gol:")
print(bayer_munich_goles)

# Calcular el total de goles del equipo Bayer Munich
bayer_munich_total_goles = bayer_munich_goles['Performance_Gls'].sum()
print("Total de goles del equipo Bayer Munich:", bayer_munich_total_goles)

print("")
# Out:
# Jugadores del equipo Bayer Munich con al menos 1 gol:
#    Unnamed: 0_level_0_Player Unnamed: 2_level_0_Pos  Progression_PrgC  \
# 7              Jamal Musiala                  MF,FW              54.0
# 5   Eric Maxim Choupo-Moting                     FW               8.0
# 23              Serge Gnabry                  FW,MF              50.0
# 13                Leroy Sané                  FW,MF              47.0
# 22                Sadio Mané                     FW              48.0
# 11            Kingsley Coman                  FW,MF              61.0
# 17                Mathys Tel                     FW               9.0
# 25             Thomas Müller                  FW,MF              21.0
# 2            Benjamin Pavard                     DF              26.0
# 8             Joshua Kimmich                     MF              25.0
# 12             Leon Goretzka                     MF              28.0
# 18          Matthijs de Ligt                     DF              12.0
# 0            Alphonso Davies                     DF             100.0
# 10              João Cancelo                  FW,DF               1.0
# 16           Marcel Sabitzer                     MF               7.0
#
#     Progression_PrgP  Progression_PrgR  Performance_Gls
# 7               82.0             146.0             11.0
# 5               40.0              73.0             10.0
# 23              62.0             145.0              9.0
# 13              90.0             121.0              7.0
# 22              33.0             129.0              6.0
# 11              41.0             193.0              5.0
# 17               8.0              36.0              4.0
# 25              60.0             119.0              4.0
# 2              124.0              55.0              3.0
# 8              210.0              43.0              3.0
# 12              83.0              42.0              3.0
# 18              81.0               7.0              2.0
# 0              106.0             130.0              1.0
# 10               7.0              21.0              1.0
# 16              52.0              19.0              1.0
# Total de goles del equipo Bayer Munich: 70.0
