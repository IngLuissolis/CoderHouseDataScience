# %%
import pandas as pd
import matplotlib.pyplot as plt

ruta_archivo = '../DataSets/2022-2023FootballPlayerStats.csv'
df = pd.read_csv(ruta_archivo, encoding='Windows-1252', sep=';')

# Ver las primeras filas del dataset
print(df.head())
# Out:
#    Rk             Player Nation   Pos         Squad            Comp  Age  \
# 0   1   Brenden Aaronson    USA  MFFW  Leeds United  Premier League   22
# 1   2   Yunis Abdelhamid    MAR    DF         Reims         Ligue 1   35
# 2   3      Himad Abdelli    FRA  MFFW        Angers         Ligue 1   23
# 3   4  Salis Abdul Samed    GHA    MF          Lens         Ligue 1   22
# 4   5    Laurent Abergel    FRA    MF       Lorient         Ligue 1   30
#
#    Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  \
# 0  2000  20      19  ...  0.17  2.54  0.51    0.0    0.0  0.00   4.86    0.34
# 1  1987  22      22  ...  0.05  0.18  1.59    0.0    0.0  0.00   6.64    2.18
# 2  1999  14       8  ...  0.00  1.05  1.40    0.0    0.0  0.00   8.14    0.93
# 3  2000  20      20  ...  0.00  0.35  0.80    0.0    0.0  0.05   6.60    0.50
# 4  1993  15      15  ...  0.00  0.23  2.02    0.0    0.0  0.00   6.51    0.31
#
#    AerLost  AerWon%
# 0     1.19     22.2
# 1     1.23     64.0
# 2     1.05     47.1
# 3     0.50     50.0
# 4     0.39     44.4
#
# [5 rows x 124 columns]

# %%
# Ver las primeras filas del dataset
print(df.head())

# Obtener la cantidad de filas y columnas del DataFrame
num_filas = df.shape[0]
num_columnas = df.shape[1]

print("Número de filas:", num_filas)
print("Número de columnas:", num_columnas)
# Out:
#    Rk             Player Nation   Pos         Squad            Comp  Age  \
# 0   1   Brenden Aaronson    USA  MFFW  Leeds United  Premier League   22
# 1   2   Yunis Abdelhamid    MAR    DF         Reims         Ligue 1   35
# 2   3      Himad Abdelli    FRA  MFFW        Angers         Ligue 1   23
# 3   4  Salis Abdul Samed    GHA    MF          Lens         Ligue 1   22
# 4   5    Laurent Abergel    FRA    MF       Lorient         Ligue 1   30
#
#    Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  \
# 0  2000  20      19  ...  0.17  2.54  0.51    0.0    0.0  0.00   4.86    0.34
# 1  1987  22      22  ...  0.05  0.18  1.59    0.0    0.0  0.00   6.64    2.18
# 2  1999  14       8  ...  0.00  1.05  1.40    0.0    0.0  0.00   8.14    0.93
# 3  2000  20      20  ...  0.00  0.35  0.80    0.0    0.0  0.05   6.60    0.50
# 4  1993  15      15  ...  0.00  0.23  2.02    0.0    0.0  0.00   6.51    0.31
#
#    AerLost  AerWon%
# 0     1.19     22.2
# 1     1.23     64.0
# 2     1.05     47.1
# 3     0.50     50.0
# 4     0.39     44.4
#
# [5 rows x 124 columns]
# Número de filas: 2689
# Número de columnas: 124

# %%
# contar la cantidad de jugadores por nacionalidad (10 nacionalidades con mayor cantidad de jugadores)
nacionalidades = df['Nation'].value_counts()

# graficar el histograma
nacionalidades.head(10).plot.bar()
plt.title('Top 10 Nacionalidades con Mayor Cantidad de Jugadores')
plt.xlabel('Nacionalidad')
plt.ylabel('Cantidad de Jugadores')
plt.show()

# %%
# Seleccionar columnas relevantes y filtrar por Nation ARG
cols = ["Player", "Nation", "Squad", "Pos", "Age", "Comp", "Goals", "G/Sh"]
df_ARG = df.loc[df["Nation"] == "ARG", cols]

# Ordenar por cantidad de goles en orden descendente
df_ARG = df_ARG.sort_values(by=["Goals"], ascending=False)

# Tomar los primeros 10 jugadores
top_10_ARG = df_ARG.head(10)

# Mostrar tabla
print(top_10_ARG.to_string(index=False))
# Out:
#                Player Nation            Squad   Pos  Age            Comp  Goals  G/Sh
#      Lautaro Martínez    ARG            Inter    FW   25         Serie A     12  0.15
#          Lionel Messi    ARG        Paris S-G  MFFW   35         Ligue 1     10  0.13
#          Paulo Dybala    ARG             Roma  MFFW   29         Serie A      8  0.16
#        Ezequiel Ávila    ARG          Osasuna  FWMF   29         La Liga      7  0.13
#   Alexis Mac Allister    ARG         Brighton    MF   24  Premier League      5  0.06
#          Ángel Correa    ARG  Atlético Madrid  MFFW   27         La Liga      5  0.17
#  Valentín Castellanos    ARG           Girona    FW   24         La Liga      4  0.07
#        Julián Álvarez    ARG  Manchester City  FWMF   23  Premier League      4  0.21
#      Nicolás González    ARG       Fiorentina  FWMF   24         Serie A      3  0.11
#        Ángel Di María    ARG         Juventus    FW   34         Serie A      3  0.12
