# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Consideraciones
#
# #### Borrar columnas - variables
#
#     Unnamed: 33_level_0_Matches
#     Unnamed: 24_level_0_Matches
#     Unnamed: 0_level_0_Player   - Squad Total
#                                 - Opponent Total
#
# #### Seleccionar:
#
#         Season: 2022-2023
#
#         League: 'Bundesliga', 'EPL', 'LaLiga', 'Ligue1', 'SeriaA'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ruta_archivo = '../DataSets/player_stats/standard_stats.csv'

df = pd.read_csv(ruta_archivo, delimiter=',')

# Seleccionar la temporada 2022-2023
df = df.loc[df['Season'] == '2022-2023']

# Seleccionar las ligas
df = df.loc[df['League'].isin(['Bundesliga', 'EPL', 'LaLiga', 'Ligue1', 'SeriaA'])]

# Eliminar las columnas
df = df.drop(columns=['Unnamed: 33_level_0_Matches', 'Unnamed: 24_level_0_Matches', 'Unnamed: 4_level_0_MP', 'Playing Time_MP'])

# Eliminar las filas
df = df.loc[df['Unnamed: 0_level_0_Player'] != "Squad Total"]
df = df.loc[df['Unnamed: 0_level_0_Player'] != "Opponent Total"]

# Obtener información sobre el conjunto de datos
df.info()

# Calcular estadísticas descriptivas
df.describe()

# Ver las primeras filas del dataset
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3361 entries, 91649 to 95203
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Season                     3361 non-null   object
#  1   League                     3361 non-null   object
#  2   Team                       3361 non-null   object
#  3   Unnamed: 0_level_0_Player  3361 non-null   object
#  4   Unnamed: 1_level_0_Nation  3358 non-null   object
#  5   Unnamed: 2_level_0_Pos     3361 non-null   object
#  6   Unnamed: 3_level_0_Age     3359 non-null   object
#  7   Playing Time_Starts        3361 non-null   float64
#  8   Playing Time_Min           2758 non-null   float64
#  9   Playing Time_90s           2761 non-null   float64
#  10  Performance_Gls            2761 non-null   float64
#  11  Performance_Ast            2761 non-null   float64
#  12  Performance_G+A            2761 non-null   float64
#  13  Performance_G-PK           2761 non-null   float64
#  14  Performance_PK             2761 non-null   float64
#  15  Performance_PKatt          2761 non-null   float64
#  16  Performance_CrdY           2761 non-null   float64
#  17  Performance_CrdR           2761 non-null   float64
#  18  Progression_PrgC           2745 non-null   float64
#  19  Progression_PrgP           2745 non-null   float64
#  20  Progression_PrgR           2745 non-null   float64
#  21  Per 90 Minutes_Gls         2758 non-null   float64
#  22  Per 90 Minutes_Ast         2758 non-null   float64
#  23  Per 90 Minutes_G+A         2758 non-null   float64
#  24  Per 90 Minutes_G-PK        2758 non-null   float64
#  25  Per 90 Minutes_G+A-PK      2758 non-null   float64
#  26  Expected_xG                2745 non-null   float64
#  27  Expected_npxG              2745 non-null   float64
#  28  Expected_xAG               2745 non-null   float64
#  29  Expected_npxG+xAG          2745 non-null   float64
#  30  Per 90 Minutes_xG          2745 non-null   float64
#  31  Per 90 Minutes_xAG         2745 non-null   float64
#  32  Per 90 Minutes_xG+xAG      2745 non-null   float64
#  33  Per 90 Minutes_npxG        2745 non-null   float64
#  34  Per 90 Minutes_npxG+xAG    2745 non-null   float64
# dtypes: float64(28), object(7)
# memory usage: 945.3+ KB
# C:\Users\eduso\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3269: DtypeWarning: Columns (6,27,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           Season League     Team Unnamed: 0_level_0_Player  \
# 91649  2022-2023    EPL  Arsenal        Gabriel Dos Santos
# 91650  2022-2023    EPL  Arsenal            Aaron Ramsdale
# 91651  2022-2023    EPL  Arsenal            William Saliba
# 91652  2022-2023    EPL  Arsenal               Bukayo Saka
# 91653  2022-2023    EPL  Arsenal           Martin Ødegaard
#
#       Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos Unnamed: 3_level_0_Age  \
# 91649                    br BRA                     DF                 25-084
# 91650                   eng ENG                     GK                 24-303
# 91651                    fr FRA                     DF                 21-354
# 91652                   eng ENG                     FW                 21-189
# 91653                    no NOR                     MF                 24-086
#
#        Playing Time_Starts  Playing Time_Min  Playing Time_90s  ...  \
# 91649                 27.0            2430.0              27.0  ...
# 91650                 27.0            2430.0              27.0  ...
# 91651                 27.0            2415.0              26.8  ...
# 91652                 27.0            2313.0              25.7  ...
# 91653                 26.0            2216.0              24.6  ...
#
#        Per 90 Minutes_G+A-PK  Expected_xG  Expected_npxG  Expected_xAG  \
# 91649                   0.11          3.5            3.5           0.2
# 91650                   0.00          0.0            0.0           0.0
# 91651                   0.11          0.9            0.9           1.1
# 91652                   0.66          8.7            7.3           6.1
# 91653                   0.65          7.0            7.0           6.3
#
#        Expected_npxG+xAG  Per 90 Minutes_xG  Per 90 Minutes_xAG  \
# 91649                3.6               0.13                0.01
# 91650                0.0               0.00                0.00
# 91651                2.0               0.03                0.04
# 91652               13.4               0.35                0.24
# 91653               13.4               0.30                0.27
#
#        Per 90 Minutes_xG+xAG  Per 90 Minutes_npxG  Per 90 Minutes_npxG+xAG
# 91649                   0.14                 0.13                     0.14
# 91650                   0.00                 0.00                     0.00
# 91651                   0.08                 0.03                     0.08
# 91652                   0.59                 0.29                     0.54
# 91653                   0.57                 0.30                     0.57
#
# [5 rows x 35 columns]

# %% [markdown]
# #### Cambiar Valores
#
#         David Ozoh:     Unnamed: 1_level_0_Nation: 'eng ENG'
#
#
# #### Borrar Filas
#
#         Alphadjo Cissè
#         Matteo Fiorenza
#         Sammy Braybroke
#
#         Eliminar las filas con Playing Time_Min = NaN
#
#          Eliminar las filas con Progression_PrgC = NaN

# %%
# Cambiar el valor de la celda en la fila 386 y columna "Nation"
df.loc[92057, 'Unnamed: 1_level_0_Nation'] = 'en ENG'

# %%
# Eliminar las filas con Playing Time_Min = NaN
df = df.dropna(subset=['Playing Time_Min'])

# Eliminar las filas con Progression_PrgC = NaN
df = df.dropna(subset=['Progression_PrgC'])

# Obtener información sobre el conjunto de datos
df.info()

# Calcular estadísticas descriptivas
df.describe()

# Ver las primeras filas del dataset
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2745 entries, 91649 to 95194
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Season                     2745 non-null   object
#  1   League                     2745 non-null   object
#  2   Team                       2745 non-null   object
#  3   Unnamed: 0_level_0_Player  2745 non-null   object
#  4   Unnamed: 1_level_0_Nation  2745 non-null   object
#  5   Unnamed: 2_level_0_Pos     2745 non-null   object
#  6   Unnamed: 3_level_0_Age     2745 non-null   object
#  7   Playing Time_Starts        2745 non-null   float64
#  8   Playing Time_Min           2745 non-null   float64
#  9   Playing Time_90s           2745 non-null   float64
#  10  Performance_Gls            2745 non-null   float64
#  11  Performance_Ast            2745 non-null   float64
#  12  Performance_G+A            2745 non-null   float64
#  13  Performance_G-PK           2745 non-null   float64
#  14  Performance_PK             2745 non-null   float64
#  15  Performance_PKatt          2745 non-null   float64
#  16  Performance_CrdY           2745 non-null   float64
#  17  Performance_CrdR           2745 non-null   float64
#  18  Progression_PrgC           2745 non-null   float64
#  19  Progression_PrgP           2745 non-null   float64
#  20  Progression_PrgR           2745 non-null   float64
#  21  Per 90 Minutes_Gls         2745 non-null   float64
#  22  Per 90 Minutes_Ast         2745 non-null   float64
#  23  Per 90 Minutes_G+A         2745 non-null   float64
#  24  Per 90 Minutes_G-PK        2745 non-null   float64
#  25  Per 90 Minutes_G+A-PK      2745 non-null   float64
#  26  Expected_xG                2745 non-null   float64
#  27  Expected_npxG              2745 non-null   float64
#  28  Expected_xAG               2745 non-null   float64
#  29  Expected_npxG+xAG          2745 non-null   float64
#  30  Per 90 Minutes_xG          2745 non-null   float64
#  31  Per 90 Minutes_xAG         2745 non-null   float64
#  32  Per 90 Minutes_xG+xAG      2745 non-null   float64
#  33  Per 90 Minutes_npxG        2745 non-null   float64
#  34  Per 90 Minutes_npxG+xAG    2745 non-null   float64
# dtypes: float64(28), object(7)
# memory usage: 772.0+ KB
#           Season League     Team Unnamed: 0_level_0_Player  \
# 91649  2022-2023    EPL  Arsenal        Gabriel Dos Santos
# 91650  2022-2023    EPL  Arsenal            Aaron Ramsdale
# 91651  2022-2023    EPL  Arsenal            William Saliba
# 91652  2022-2023    EPL  Arsenal               Bukayo Saka
# 91653  2022-2023    EPL  Arsenal           Martin Ødegaard
#
#       Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos Unnamed: 3_level_0_Age  \
# 91649                    br BRA                     DF                 25-084
# 91650                   eng ENG                     GK                 24-303
# 91651                    fr FRA                     DF                 21-354
# 91652                   eng ENG                     FW                 21-189
# 91653                    no NOR                     MF                 24-086
#
#        Playing Time_Starts  Playing Time_Min  Playing Time_90s  ...  \
# 91649                 27.0            2430.0              27.0  ...
# 91650                 27.0            2430.0              27.0  ...
# 91651                 27.0            2415.0              26.8  ...
# 91652                 27.0            2313.0              25.7  ...
# 91653                 26.0            2216.0              24.6  ...
#
#        Per 90 Minutes_G+A-PK  Expected_xG  Expected_npxG  Expected_xAG  \
# 91649                   0.11          3.5            3.5           0.2
# 91650                   0.00          0.0            0.0           0.0
# 91651                   0.11          0.9            0.9           1.1
# 91652                   0.66          8.7            7.3           6.1
# 91653                   0.65          7.0            7.0           6.3
#
#        Expected_npxG+xAG  Per 90 Minutes_xG  Per 90 Minutes_xAG  \
# 91649                3.6               0.13                0.01
# 91650                0.0               0.00                0.00
# 91651                2.0               0.03                0.04
# 91652               13.4               0.35                0.24
# 91653               13.4               0.30                0.27
#
#        Per 90 Minutes_xG+xAG  Per 90 Minutes_npxG  Per 90 Minutes_npxG+xAG
# 91649                   0.14                 0.13                     0.14
# 91650                   0.00                 0.00                     0.00
# 91651                   0.08                 0.03                     0.08
# 91652                   0.59                 0.29                     0.54
# 91653                   0.57                 0.30                     0.57
#
# [5 rows x 35 columns]

# %%
# Cambiar los datos de la columna Unnamed: 3_level_0_Age
df['Unnamed: 3_level_0_Age'] = df['Unnamed: 3_level_0_Age'].str[:2].astype('float64')

# Obtener información sobre el conjunto de datos
df.info()

# Calcular estadísticas descriptivas
df.describe()

# Ver las primeras filas del dataset
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2745 entries, 91649 to 95194
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Season                     2745 non-null   object
#  1   League                     2745 non-null   object
#  2   Team                       2745 non-null   object
#  3   Unnamed: 0_level_0_Player  2745 non-null   object
#  4   Unnamed: 1_level_0_Nation  2745 non-null   object
#  5   Unnamed: 2_level_0_Pos     2745 non-null   object
#  6   Unnamed: 3_level_0_Age     2745 non-null   float64
#  7   Playing Time_Starts        2745 non-null   float64
#  8   Playing Time_Min           2745 non-null   float64
#  9   Playing Time_90s           2745 non-null   float64
#  10  Performance_Gls            2745 non-null   float64
#  11  Performance_Ast            2745 non-null   float64
#  12  Performance_G+A            2745 non-null   float64
#  13  Performance_G-PK           2745 non-null   float64
#  14  Performance_PK             2745 non-null   float64
#  15  Performance_PKatt          2745 non-null   float64
#  16  Performance_CrdY           2745 non-null   float64
#  17  Performance_CrdR           2745 non-null   float64
#  18  Progression_PrgC           2745 non-null   float64
#  19  Progression_PrgP           2745 non-null   float64
#  20  Progression_PrgR           2745 non-null   float64
#  21  Per 90 Minutes_Gls         2745 non-null   float64
#  22  Per 90 Minutes_Ast         2745 non-null   float64
#  23  Per 90 Minutes_G+A         2745 non-null   float64
#  24  Per 90 Minutes_G-PK        2745 non-null   float64
#  25  Per 90 Minutes_G+A-PK      2745 non-null   float64
#  26  Expected_xG                2745 non-null   float64
#  27  Expected_npxG              2745 non-null   float64
#  28  Expected_xAG               2745 non-null   float64
#  29  Expected_npxG+xAG          2745 non-null   float64
#  30  Per 90 Minutes_xG          2745 non-null   float64
#  31  Per 90 Minutes_xAG         2745 non-null   float64
#  32  Per 90 Minutes_xG+xAG      2745 non-null   float64
#  33  Per 90 Minutes_npxG        2745 non-null   float64
#  34  Per 90 Minutes_npxG+xAG    2745 non-null   float64
# dtypes: float64(29), object(6)
# memory usage: 772.0+ KB
#           Season League     Team Unnamed: 0_level_0_Player  \
# 91649  2022-2023    EPL  Arsenal        Gabriel Dos Santos
# 91650  2022-2023    EPL  Arsenal            Aaron Ramsdale
# 91651  2022-2023    EPL  Arsenal            William Saliba
# 91652  2022-2023    EPL  Arsenal               Bukayo Saka
# 91653  2022-2023    EPL  Arsenal           Martin Ødegaard
#
#       Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 91649                    br BRA                     DF
# 91650                   eng ENG                     GK
# 91651                    fr FRA                     DF
# 91652                   eng ENG                     FW
# 91653                    no NOR                     MF
#
#        Unnamed: 3_level_0_Age  Playing Time_Starts  Playing Time_Min  \
# 91649                    25.0                 27.0            2430.0
# 91650                    24.0                 27.0            2430.0
# 91651                    21.0                 27.0            2415.0
# 91652                    21.0                 27.0            2313.0
# 91653                    24.0                 26.0            2216.0
#
#        Playing Time_90s  ...  Per 90 Minutes_G+A-PK  Expected_xG  \
# 91649              27.0  ...                   0.11          3.5
# 91650              27.0  ...                   0.00          0.0
# 91651              26.8  ...                   0.11          0.9
# 91652              25.7  ...                   0.66          8.7
# 91653              24.6  ...                   0.65          7.0
#
#        Expected_npxG  Expected_xAG  Expected_npxG+xAG  Per 90 Minutes_xG  \
# 91649            3.5           0.2                3.6               0.13
# 91650            0.0           0.0                0.0               0.00
# 91651            0.9           1.1                2.0               0.03
# 91652            7.3           6.1               13.4               0.35
# 91653            7.0           6.3               13.4               0.30
#
#        Per 90 Minutes_xAG  Per 90 Minutes_xG+xAG  Per 90 Minutes_npxG  \
# 91649                0.01                   0.14                 0.13
# 91650                0.00                   0.00                 0.00
# 91651                0.04                   0.08                 0.03
# 91652                0.24                   0.59                 0.29
# 91653                0.27                   0.57                 0.30
#
#        Per 90 Minutes_npxG+xAG
# 91649                     0.14
# 91650                     0.00
# 91651                     0.08
# 91652                     0.54
# 91653                     0.57
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Guardar los datos en un archivo nuevo CSV

# %%
df.to_csv("../DataSets/player_stats/standard_stats_Corr.csv")

# %% [markdown]
# ## Extraer los datos de nuevo archivo

# %%
ruta_archivo = '../DataSets/player_stats/standard_stats_Corr.csv'

df = pd.read_csv(ruta_archivo, delimiter=',')

# Obtener información sobre el conjunto de datos
df.info()

# Calcular estadísticas descriptivas
df.describe()

# Ver las primeras filas del dataset
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2745 entries, 0 to 2744
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 2745 non-null   int64
#  1   Season                     2745 non-null   object
#  2   League                     2745 non-null   object
#  3   Team                       2745 non-null   object
#  4   Unnamed: 0_level_0_Player  2745 non-null   object
#  5   Unnamed: 1_level_0_Nation  2745 non-null   object
#  6   Unnamed: 2_level_0_Pos     2745 non-null   object
#  7   Unnamed: 3_level_0_Age     2745 non-null   float64
#  8   Playing Time_Starts        2745 non-null   float64
#  9   Playing Time_Min           2745 non-null   float64
#  10  Playing Time_90s           2745 non-null   float64
#  11  Performance_Gls            2745 non-null   float64
#  12  Performance_Ast            2745 non-null   float64
#  13  Performance_G+A            2745 non-null   float64
#  14  Performance_G-PK           2745 non-null   float64
#  15  Performance_PK             2745 non-null   float64
#  16  Performance_PKatt          2745 non-null   float64
#  17  Performance_CrdY           2745 non-null   float64
#  18  Performance_CrdR           2745 non-null   float64
#  19  Progression_PrgC           2745 non-null   float64
#  20  Progression_PrgP           2745 non-null   float64
#  21  Progression_PrgR           2745 non-null   float64
#  22  Per 90 Minutes_Gls         2745 non-null   float64
#  23  Per 90 Minutes_Ast         2745 non-null   float64
#  24  Per 90 Minutes_G+A         2745 non-null   float64
#  25  Per 90 Minutes_G-PK        2745 non-null   float64
#  26  Per 90 Minutes_G+A-PK      2745 non-null   float64
#  27  Expected_xG                2745 non-null   float64
#  28  Expected_npxG              2745 non-null   float64
#  29  Expected_xAG               2745 non-null   float64
#  30  Expected_npxG+xAG          2745 non-null   float64
#  31  Per 90 Minutes_xG          2745 non-null   float64
#  32  Per 90 Minutes_xAG         2745 non-null   float64
#  33  Per 90 Minutes_xG+xAG      2745 non-null   float64
#  34  Per 90 Minutes_npxG        2745 non-null   float64
#  35  Per 90 Minutes_npxG+xAG    2745 non-null   float64
# dtypes: float64(29), int64(1), object(6)
# memory usage: 772.2+ KB
#    Unnamed: 0     Season League     Team Unnamed: 0_level_0_Player  \
# 0       91649  2022-2023    EPL  Arsenal        Gabriel Dos Santos
# 1       91650  2022-2023    EPL  Arsenal            Aaron Ramsdale
# 2       91651  2022-2023    EPL  Arsenal            William Saliba
# 3       91652  2022-2023    EPL  Arsenal               Bukayo Saka
# 4       91653  2022-2023    EPL  Arsenal           Martin Ødegaard
#
#   Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  Unnamed: 3_level_0_Age  \
# 0                    br BRA                     DF                    25.0
# 1                   eng ENG                     GK                    24.0
# 2                    fr FRA                     DF                    21.0
# 3                   eng ENG                     FW                    21.0
# 4                    no NOR                     MF                    24.0
#
#    Playing Time_Starts  Playing Time_Min  ...  Per 90 Minutes_G+A-PK  \
# 0                 27.0            2430.0  ...                   0.11
# 1                 27.0            2430.0  ...                   0.00
# 2                 27.0            2415.0  ...                   0.11
# 3                 27.0            2313.0  ...                   0.66
# 4                 26.0            2216.0  ...                   0.65
#
#    Expected_xG  Expected_npxG  Expected_xAG  Expected_npxG+xAG  \
# 0          3.5            3.5           0.2                3.6
# 1          0.0            0.0           0.0                0.0
# 2          0.9            0.9           1.1                2.0
# 3          8.7            7.3           6.1               13.4
# 4          7.0            7.0           6.3               13.4
#
#    Per 90 Minutes_xG  Per 90 Minutes_xAG  Per 90 Minutes_xG+xAG  \
# 0               0.13                0.01                   0.14
# 1               0.00                0.00                   0.00
# 2               0.03                0.04                   0.08
# 3               0.35                0.24                   0.59
# 4               0.30                0.27                   0.57
#
#    Per 90 Minutes_npxG  Per 90 Minutes_npxG+xAG
# 0                 0.13                     0.14
# 1                 0.00                     0.00
# 2                 0.03                     0.08
# 3                 0.29                     0.54
# 4                 0.30                     0.57
#
# [5 rows x 36 columns]
